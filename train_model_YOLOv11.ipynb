# %%
# !pip install ultralytics

# %%
# Run in Colab

from roboflow import Roboflow
from ultralytics import YOLO
from google.colab import drive, userdata

drive.mount('/content/drive')     

apiKey = userdata.get('ROBOFLOW_API_KEY')
rf = Roboflow(api_key=apiKey)
project = rf.workspace("projects-vnzqz").project("tennis-ball-obj-det-cyjrp-thstm-vl2fz")
version = project.version(1)
# dataset = version.download("yolov11")


# Load a model
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="/content/Tennis-Ball-Obj-Det-1/data.yaml", epochs=100, imgsz=640)

# %%
# !ls
